# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import pandas as pd
import polyglot
import os
from polyglot.text import Text, Word
from polyglot.mapping import Embedding
from polyglot.detect import Detector

import nltk
from nltk.corpus import stopwords
import numpy as np
import random






__file__ = os.getcwd()
dirname = os.path.dirname(__file__)
input_file = os.path.join(dirname, 'scripts\\data\\dogodki_stripped.csv')
df = pd.read_csv(input_file, header = 0)
original_headers = list(df.columns.values)
data_opis = df['opis'].astype('U')


_SAMPLE_SIZE = 150
sampled_list = random.sample(list(data_opis), _SAMPLE_SIZE)

delezByCountry = []

for row in sampled_list:
    try:
        detector = Detector(str(row), quiet=True)
        dog = {}
        for language in detector.languages:
            if language.code != 'un':
                print(language)
                dist = {
                "code": language.code,
                "confidence": language.confidence,
                "count": len(str(row)) * (language.confidence / 100)
                }
                dog[language.code] = dist
        delezByCountry.append(dog)
    except:
        print('Preskočen.')



N = len(delezByCountry)
slDelez = [0] * N
enDelez = [0] * N

slStevilo = [0] * N
enStevilo = [0] * N

for i in range(len(delezByCountry)):
    if('sl' in delezByCountry[i]):
        slDelez[i] = delezByCountry[i]['sl']['confidence']
        slStevilo[i] = delezByCountry[i]['sl']['count']
    if('en' in delezByCountry[i]):
        enDelez[i] = delezByCountry[i]['en']['confidence']
        enStevilo[i] = delezByCountry[i]['en']['count']

    
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, slDelez, width)
p2 = plt.bar(ind, enDelez, width,
             bottom=slDelez)

plt.ylabel('Delez')
plt.title('Delez Slovenskih in Angleških besed')
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Slo', 'Eng'))

plt.show()


x = np.arange(N)  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, slStevilo, width, label='SL')
rects2 = ax.bar(x + width/2, enStevilo, width, label='EN')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Število')
ax.set_title('Število')
#ax.set_xticks(x)
#ax.set_xticklabels(labels)
ax.legend()
fig.tight_layout()
plt.show()


#text = Text(row)
#word = Word(row)

#stopwords = stopwords.words('slovene')

#print(stopwords)
#print(row)

""" print('-------------------------------------------------')

for row in text.words:
    try:
        print(row)
        detector = Detector(str(row), quiet=True)
        for language in detector.languages:
            if language.code != 'un':
                print(language)
    except:
        print('Preskočen.')
print('-------------------------------------------------')
print(text.entities)
print(text.morphemes)
 """
# Out:
# name: slovenščina code: sl       confidence:  83.0 read bytes:   519
# name: slovenščina code: sl       confidence:  99.0 read bytes:   502
# name: slovenščina code: sl       confidence:  88.0 read bytes:   471
# name: slovenščina code: sl       confidence:  86.0 read bytes:   544
# name: slovenščina code: sl       confidence:  65.0 read bytes:   516
# name: angleščina  code: en       confidence:  34.0 read bytes:   311
# name: slovenščina code: sl       confidence:  99.0 read bytes:   465
# name: slovenščina code: sl       confidence:  99.0 read bytes:   600
# name: slovenščina code: sl       confidence:  99.0 read bytes:   431
# name: slovenščina code: sl       confidence:  71.0 read bytes:   436
# name: angleščina  code: en       confidence:  28.0 read bytes:   372
# name: slovenščina code: sl       confidence:  99.0 read bytes:   394
# name: slovenščina code: sl       confidence:  99.0 read bytes:   662
# name: slovenščina code: sl       confidence:  99.0 read bytes:   632
# name: slovenščina code: sl       confidence:  99.0 read bytes:   628
# name: slovenščina code: sl       confidence:  97.0 read bytes:   558
# name: slovenščina code: sl       confidence:  99.0 read bytes:   530
# name: slovenščina code: sl       confidence:  78.0 read bytes:   394
# name: srbščina    code: sr       confidence:  21.0 read bytes:   171
# name: slovenščina code: sl       confidence:  99.0 read bytes:   648
# name: slovenščina code: sl       confidence:  99.0 read bytes:   470
# name: slovenščina code: sl       confidence:  99.0 read bytes:   598
# name: slovenščina code: sl       confidence:  99.0 read bytes:   319
# name: slovenščina code: sl       confidence:  87.0 read bytes:   430
# name: srbščina    code: sr       confidence:  12.0 read bytes:   343
# name: slovenščina code: sl       confidence:  65.0 read bytes:   641
# name: srbščina    code: sr       confidence:  34.0 read bytes:   682
# name: slovenščina code: sl       confidence:  52.0 read bytes:   551
# name: angleščina  code: en       confidence:  47.0 read bytes:   517
# name: angleščina  code: en       confidence:  48.0 read bytes:   708
# name: slovenščina code: sl       confidence:  38.0 read bytes:   387
# name: slovenščina code: sl       confidence:  99.0 read bytes:   674
# name: angleščina  code: en       confidence:  57.0 read bytes:   478
# name: slovenščina code: sl       confidence:  42.0 read bytes:   574
# name: slovenščina code: sl       confidence:  99.0 read bytes:   486
# name: slovenščina code: sl       confidence:  99.0 read bytes:   702
# name: slovenščina code: sl       confidence:  99.0 read bytes:   433
# name: slovenščina code: sl       confidence:  99.0 read bytes:   532
# name: slovenščina code: sl       confidence:  98.0 read bytes:   686
# name: slovenščina code: sl       confidence:  99.0 read bytes:   548
# name: slovenščina code: sl       confidence:  99.0 read bytes:   578
# name: slovenščina code: sl       confidence:  99.0 read bytes:   568
# name: slovenščina code: sl       confidence:  99.0 read bytes:   605
# name: slovaščina  code: sk       confidence:  98.0 read bytes:   409
# name: angleščina  code: en       confidence:  99.0 read bytes:   495
# name: slovenščina code: sl       confidence:  54.0 read bytes:   544
# name: angleščina  code: en       confidence:  45.0 read bytes:   189
# name: slovenščina code: sl       confidence:  92.0 read bytes:   512
# name: slovenščina code: sl       confidence:  70.0 read bytes:   452
# name: srbščina    code: sr       confidence:  29.0 read bytes:   278
# name: slovenščina code: sl       confidence:  99.0 read bytes:   529
# name: slovenščina code: sl       confidence:  99.0 read bytes:   552
# name: angleščina  code: en       confidence:  96.0 read bytes:   676
# name: italijanščinacode: it       confidence:   3.0 read bytes:   686
# name: slovenščina code: sl       confidence:  99.0 read bytes:   510
# name: slovenščina code: sl       confidence:  99.0 read bytes:   619
# name: slovenščina code: sl       confidence:  90.0 read bytes:   470
# name: slovenščina code: sl       confidence:  99.0 read bytes:   667
# name: slovenščina code: sl       confidence:  87.0 read bytes:   419
# name: angleščina  code: en       confidence:  12.0 read bytes:   505
# name: slovenščina code: sl       confidence:  99.0 read bytes:   482
# name: slovenščina code: sl       confidence:  75.0 read bytes:   383
# name: angleščina  code: en       confidence:  24.0 read bytes:   273
# name: slovenščina code: sl       confidence:  99.0 read bytes:   458
# name: slovenščina code: sl       confidence:  99.0 read bytes:   552
# name: slovenščina code: sl       confidence:  50.0 read bytes:   536
# name: angleščina  code: en       confidence:  49.0 read bytes:   209
# name: angleščina  code: en       confidence:  52.0 read bytes:   658
# name: slovenščina code: sl       confidence:  47.0 read bytes:   603
# name: slovenščina code: sl       confidence:  87.0 read bytes:   433
# name: slovenščina code: sl       confidence:  99.0 read bytes:   369
# name: slovenščina code: sl       confidence:  99.0 read bytes:   416
# name: slovenščina code: sl       confidence:  99.0 read bytes:   520
# name: slovenščina code: sl       confidence:  99.0 read bytes:   688
# name: slovenščina code: sl       confidence:  61.0 read bytes:   377
# name: italijanščinacode: it       confidence:  38.0 read bytes:   243
# name: slovenščina code: sl       confidence:  99.0 read bytes:   586
# name: slovenščina code: sl       confidence:  99.0 read bytes:   254
# name: angleščina  code: en       confidence:  52.0 read bytes:   566
# name: slovenščina code: sl       confidence:  47.0 read bytes:   333
# name: angleščina  code: en       confidence:  99.0 read bytes:   400
# name: angleščina  code: en       confidence:  99.0 read bytes:   315
# name: slovenščina code: sl       confidence:  99.0 read bytes:   509
# name: slovenščina code: sl       confidence:  99.0 read bytes:   586
# name: slovenščina code: sl       confidence:  63.0 read bytes:   429
# name: angleščina  code: en       confidence:  36.0 read bytes:   614
# name: hrvaščina   code: hr       confidence:  42.0 read bytes:   245
# name: češčina     code: cs       confidence:  12.0 read bytes:   229
# name: bosanščina  code: bs       confidence:   9.0 read bytes:   369
# name: angleščina  code: en       confidence:  84.0 read bytes:   311
# name: slovenščina code: sl       confidence:  15.0 read bytes:   196
# name: slovenščina code: sl       confidence:  86.0 read bytes:   481
# name: angleščina  code: en       confidence:  13.0 read bytes:   526
# name: slovenščina code: sl       confidence:  99.0 read bytes:   483
# name: slovenščina code: sl       confidence:  99.0 read bytes:   441
# name: slovenščina code: sl       confidence:  99.0 read bytes:   603
# name: angleščina  code: en       confidence:  79.0 read bytes:   468
# name: slovenščina code: sl       confidence:  20.0 read bytes:   748
# name: slovenščina code: sl       confidence:  99.0 read bytes:   439
# name: slovenščina code: sl       confidence:  99.0 read bytes:   583
# name: slovenščina code: sl       confidence:  99.0 read bytes:   540
# name: slovenščina code: sl       confidence:  99.0 read bytes:   572
# name: nemščina    code: de       confidence:  99.0 read bytes:   810
# name: angleščina  code: en       confidence:  82.0 read bytes:   290
# name: slovenščina code: sl       confidence:  17.0 read bytes:   400
# name: slovenščina code: sl       confidence:  89.0 read bytes:   492
# name: slovenščina code: sl       confidence:  99.0 read bytes:   465
# name: angleščina  code: en       confidence:  58.0 read bytes:   356
# name: slovenščina code: sl       confidence:  34.0 read bytes:   343
# name: hrvaščina   code: hr       confidence:   2.0 read bytes:   222
# name: slovenščina code: sl       confidence:  99.0 read bytes:   834
# name: slovenščina code: sl       confidence:  62.0 read bytes:   517
# name: angleščina  code: en       confidence:  37.0 read bytes:   720
# name: slovenščina code: sl       confidence:  58.0 read bytes:   455
# name: angleščina  code: en       confidence:  41.0 read bytes:   414
# name: angleščina  code: en       confidence:  53.0 read bytes:   699
# name: slovenščina code: sl       confidence:  46.0 read bytes:   544
# name: slovenščina code: sl       confidence:  99.0 read bytes:   443
# name: slovenščina code: sl       confidence:  67.0 read bytes:   398
# name: angleščina  code: en       confidence:  32.0 read bytes:   240
# name: slovenščina code: sl       confidence:  99.0 read bytes:   312
# name: slovenščina code: sl       confidence:  75.0 read bytes:   524
# name: angleščina  code: en       confidence:  11.0 read bytes:   539
# name: slovenščina code: sl       confidence:  99.0 read bytes:   430
# name: slovenščina code: sl       confidence:  99.0 read bytes:   430
# name: slovenščina code: sl       confidence:  99.0 read bytes:   614
# name: slovenščina code: sl       confidence:  99.0 read bytes:   540
# name: slovenščina code: sl       confidence:  63.0 read bytes:   291
# name: angleščina  code: en       confidence:  36.0 read bytes:   261
# name: angleščina  code: en       confidence:  68.0 read bytes:   510
# name: slovenščina code: sl       confidence:  31.0 read bytes:   567
# name: slovenščina code: sl       confidence:  99.0 read bytes:   624
# name: slovenščina code: sl       confidence:  99.0 read bytes:   614
# name: slovenščina code: sl       confidence:  98.0 read bytes:   403
# name: slovenščina code: sl       confidence:  99.0 read bytes:   474
# name: slovenščina code: sl       confidence:  99.0 read bytes:   623
# name: slovenščina code: sl       confidence:  99.0 read bytes:   358
# name: slovenščina code: sl       confidence:  99.0 read bytes:   599
# name: slovenščina code: sl       confidence:  99.0 read bytes:   566
# name: slovenščina code: sl       confidence:  99.0 read bytes:   505
# name: slovenščina code: sl       confidence:  99.0 read bytes:   543
# name: slovenščina code: sl       confidence:  99.0 read bytes:   492
# name: nizozemščinacode: nl       confidence:  99.0 read bytes:   899
# name: slovenščina code: sl       confidence:  99.0 read bytes:   576
# name: slovenščina code: sl       confidence:  99.0 read bytes:   512
# name: slovenščina code: sl       confidence:  33.0 read bytes:   524
# name: angleščina  code: en       confidence:  29.0 read bytes:   363
# name: nemščina    code: de       confidence:  21.0 read bytes:   775
# name: slovenščina code: sl       confidence:  74.0 read bytes:   310
# name: angleščina  code: en       confidence:  25.0 read bytes:   224
# name: slovenščina code: sl       confidence:  99.0 read bytes:   532
# name: slovenščina code: sl       confidence:  99.0 read bytes:   584
# name: slovenščina code: sl       confidence:  99.0 read bytes:   514
# name: slovenščina code: sl       confidence:  99.0 read bytes:   420
# name: angleščina  code: en       confidence:  87.0 read bytes:   454
# name: slovenščina code: sl       confidence:  99.0 read bytes:   667
# name: angleščina  code: en       confidence:  76.0 read bytes:   481
# name: slovaščina  code: sk       confidence:  11.0 read bytes:   184
# name: sejšelska francoska kreolščinacode: crs      confidence:  10.0 read bytes:   118
# name: slovenščina code: sl       confidence:  99.0 read bytes:   524
# name: slovenščina code: sl       confidence:  99.0 read bytes:   427
# name: slovenščina code: sl       confidence:  81.0 read bytes:   620
# name: slovenščina code: sl       confidence:  99.0 read bytes:   502
# name: slovenščina code: sl       confidence:  99.0 read bytes:   585
# name: slovenščina code: sl       confidence:  99.0 read bytes:   478
# name: slovenščina code: sl       confidence:  88.0 read bytes:   409
# name: nemščina    code: de       confidence:  91.0 read bytes:   935
# name: angleščina  code: en       confidence:   8.0 read bytes:   609
# name: slovenščina code: sl       confidence:  99.0 read bytes:   418
# name: angleščina  code: en       confidence:  56.0 read bytes:   618
# name: slovenščina code: sl       confidence:  43.0 read bytes:   555
# name: slovenščina code: sl       confidence:  99.0 read bytes:   440
# name: slovenščina code: sl       confidence:  99.0 read bytes:   413
# name: slovenščina code: sl       confidence:  99.0 read bytes:   370
# name: slovenščina code: sl       confidence:  99.0 read bytes:   472
# name: slovenščina code: sl       confidence:  80.0 read bytes:   381
# name: slovenščina code: sl       confidence:  99.0 read bytes:   684
# name: slovenščina code: sl       confidence:  99.0 read bytes:   496
# name: slovenščina code: sl       confidence:  99.0 read bytes:   366
# name: angleščina  code: en       confidence:  54.0 read bytes:   650
# name: slovenščina code: sl       confidence:  45.0 read bytes:   657
# name: slovenščina code: sl       confidence:  99.0 read bytes:   674
# name: slovenščina code: sl       confidence:  99.0 read bytes:   500
# name: slovenščina code: sl       confidence:  99.0 read bytes:   412
# name: slovenščina code: sl       confidence:  99.0 read bytes:   521
# name: slovenščina code: sl       confidence:  99.0 read bytes:   425
# name: angleščina  code: en       confidence:  69.0 read bytes:   698
# name: slovenščina code: sl       confidence:  30.0 read bytes:   410
# name: slovenščina code: sl       confidence:  69.0 read bytes:   361
# name: angleščina  code: en       confidence:  30.0 read bytes:   269
# name: slovenščina code: sl       confidence:  99.0 read bytes:   397
# name: angleščina  code: en       confidence:  47.0 read bytes:   457
# name: slovenščina code: sl       confidence:  27.0 read bytes:   328
# name: srbščina    code: sr       confidence:  13.0 read bytes:   255
# name: slovenščina code: sl       confidence:  99.0 read bytes:   394
# " print('-------------------------------------------------')\n\nfor row in text.words:\n    try:\n        print(row)\n        detector = Detector(str(row), quiet=True)\n        for language in detector.languages:\n            if language.code != 'un':\n                print(language)\n    except:\n        print('Preskočen.')\nprint('-------------------------------------------------')\nprint(text.entities)\nprint(text.morphemes)\n "
